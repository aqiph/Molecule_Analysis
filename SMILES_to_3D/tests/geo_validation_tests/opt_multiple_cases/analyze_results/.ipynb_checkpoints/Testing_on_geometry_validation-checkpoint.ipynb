# %% [markdown]
# # Testing on geometry validation

# %% [markdown]
# Geometry change after DFT optimization:
#
# Geometry change is defined as the bondlength (atom-atom distance) change within a cutoff radius defined by the unoptimized structure

# %% [markdown]
# Cutoff radius = 3 A

# %% [markdown]
# ![bondlength_change_dist_all.png](attachment:bondlength_change_dist_all.png)

# %% [markdown]
# ![bondlength_change_dist_C-C.png](attachment:bondlength_change_dist_C-C.png)

# %% [markdown]
# ![bondlength_change_dist_C-H.png](attachment:bondlength_change_dist_C-H.png)

# %% [markdown]
# ![bondlength_change_dist_C-O.png](attachment:bondlength_change_dist_C-O.png)

# %% [markdown]
# ![bondlength_change_dist_H-O.png](attachment:bondlength_change_dist_H-O.png)

# %% [markdown]
# Cutoff radius = 5 A

# %% [markdown]
# ![bondlength_change_dist_all.png](attachment:bondlength_change_dist_all.png)

# %% [markdown]
# ![bondlength_change_dist_C-C.png](attachment:bondlength_change_dist_C-C.png)

# %% [markdown]
# ![bondlength_change_dist_C-H.png](attachment:bondlength_change_dist_C-H.png)

# %% [markdown]
# ![bondlength_change_dist_C-O.png](attachment:bondlength_change_dist_C-O.png)

# %% [markdown]
# ![bondlength_change_H-O.png](attachment:bondlength_change_H-O.png)

# %% [markdown]
# Cutoff radius = 7 A

# %% [markdown]
# ![bondlength_change_dist_all.png](attachment:bondlength_change_dist_all.png)

# %% [markdown]
# ![bondlength_change_dist_C-C.png](attachment:bondlength_change_dist_C-C.png)

# %% [markdown]
# ![bondlength_change_dist_C-H.png](attachment:bondlength_change_dist_C-H.png)

# %% [markdown]
# ![bondlength_change_dist_C-O.png](attachment:bondlength_change_dist_C-O.png)

# %% [markdown]
# ![bondlength_change_dist_H-O.png](attachment:bondlength_change_dist_H-O.png)

# %% [markdown]
# conclusion:
# 1. Shorter bonds has smaller bondlength change after geometry optimization => rdkit-generated 3D structures are accurate for covalent bonds
# 2. Among common bond types, C-C and C-O bonds have smaller structural change after DFT calculations, followed by C-H bonds. H-O bonds are the worst.
