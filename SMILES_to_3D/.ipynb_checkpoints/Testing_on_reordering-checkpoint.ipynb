# %% [markdown]
# # Testing on canonical reordering

# %% [markdown]
# ###################################################################
#
# Test 1
#
# smiles to molecule -> add H -> compute order, renumber atoms -> opt
#
# Add map number: Mapping numbers do not change after Chem.RenumberAtoms(). The generated 3D structures are not the same for molecule1 and molecule2.
# ![fig_before_test1_mapnum.png](attachment:fig_before_test1_mapnum.png)
# Fig 1. Molecule 1 before reorder

# %% [markdown]
# ![fig_after_test1_mapnum.png](attachment:fig_after_test1_mapnum.png)
# Fig 2. Molecule 1 after reorder

# %% [markdown]
# Add atom indices: indices have changed, but are different for molecule1 and molecule2 after Chem.RenumberAtoms(). The generated 3D structures are not the same for molecule1 and molecule2.
# ![fig_before_test1_indices.png](attachment:fig_before_test1_indices.png)
# Fig 3. Molecule 1 before reorder

# %% [markdown]
# ![fig_after_test1_indices.png](attachment:fig_after_test1_indices.png)
# Fig 4. Molecule 1 after reorder

# %% [markdown]
# ![fig_before_test2_indices.png](attachment:fig_before_test2_indices.png)
# Fig 5. Molecule 2 before reorder

# %% [markdown]
# ![fig_after_test2_indices.png](attachment:fig_after_test2_indices.png)
# Fig 6. Molecule 2 after reorder

# %% [markdown]
# ###################################################################
#
# Test 2
#
# smiles to molecule -> compute order, renumber atoms -> add H -> opt
#
# Add map number: Mapping numbers do not change after Chem.RenumberAtoms(). The generated 3D structures are not the same for molecule1 and molecule2.
#
# Add atom indices: indices have changed, and are the same for molecule1 and molecule2 after Chem.RenumberAtoms(). The generated 3D structures are the same for molecule1 and molecule2.
#
# ![fig_before_test1_indices.png](attachment:fig_before_test1_indices.png)
# Fig 7. Molecule 1 before reorder

# %% [markdown]
# ![fig_after_test1_indices.png](attachment:fig_after_test1_indices.png)
# Fig 8. Molecule 1 after reorder

# %% [markdown]
# ![fig_before_test2_indices.png](attachment:fig_before_test2_indices.png)
# Fig 9. Molecule 2 before reorder

# %% [markdown]
# ![fig_after_test2_indices.png](attachment:fig_after_test2_indices.png)
# Fig 10. Molecule 2 after reorder

# %% [markdown]
# ###################################################################
#
# Test 3
#
# smiles to molecule -> add H -> compute order, renumber atoms -> convert to smiles, convert to molecule -> opt
#
# Add map number: Mapping numbers do not change after Chem.RenumberAtoms() or after converting to smiles then converting back to molecule. The generated 3D structures are not the same for molecule1 and molecule2.
#
# Add atom indices: indices have changed, but are different for molecule1 and molecule2 after Chem.RenumberAtoms(). The indices are the same for molecule1 and molecule2 after converting to smiles and converting back to mol objects. The generated 3D structures are the same for molecule1 and molecule2.
#
#
# ![fig_before_test1_indices.png](attachment:fig_before_test1_indices.png)
# Fig 11. Molecule 1 before reorder

# %% [markdown]
# ![fig_afterReorder_test1_indices.png](attachment:fig_afterReorder_test1_indices.png)
# Fig 12. Molecule 1 after reorder

# %% [markdown]
# ![fig_fin_test1_indices.png](attachment:fig_fin_test1_indices.png)
# Fig 13. Molecule 1 after converting to smiles and then converting back to molecule

# %% [markdown]
# ![fig_before_test2_indices.png](attachment:fig_before_test2_indices.png)
# Fig 14. Molecule 2 before reorder

# %% [markdown]
# ![fig_afterReorder_test2_indices.png](attachment:fig_afterReorder_test2_indices.png)
# Fig 15. Molecule 2 after reorder

# %% [markdown]
# ![fig_fin_test2_indices.png](attachment:fig_fin_test2_indices.png)
# Fig 16. Molecule 2 after converting to smiles and then converting back to molecule

# %% [markdown]
# ###################################################################
#
# Test 4
#
# smiles to molecule -> add H -> different method to compute order, renumber atoms -> opt
#
# Add map number: Mapping numbers do not change after Chem.RenumberAtoms(). The generated 3D structures are not the same for molecule1 and molecule2.
#
# Add atom indices: indices have changed, and are the same for molecule1 and molecule2 after Chem.RenumberAtoms(). The generated 3D structures are the same for molecule1 and molecule2.
#
# ![fig_before_test1_indices.png](attachment:fig_before_test1_indices.png)
# Fig 17. Molecule 1 before reorder

# %% [markdown]
# ![fig_after_test1_indices.png](attachment:fig_after_test1_indices.png)
# Fig 18. Molecule 1 after reorder

# %% [markdown]
# ![fig_before_test2_indices.png](attachment:fig_before_test2_indices.png)
# Fig 19. Molecule 2 before reorder

# %% [markdown]
# ![fig_after_test2_indices.png](attachment:fig_after_test2_indices.png)
# Fig 20. Molecule2 after reorder

# %% [markdown]
# Remark:
#
# 1. The structures obtained from 'add atom indices' in Test 2, Test 3 and Test 4 have the same geometries (rotationally and translationally different) and the same smiles.
#
# 2. The structures obtained from 'add atom indices' in Test 1 have different geometries, but the same smiles.
